# %% [markdown]
# # Type Casting
# conversion of types

# %% [markdown]
# ## IMPLICIT:
# auto converted by compiler from small types to large types
# int -> float

# %% [markdown]
# ## Explicit
# done by programmer

# %% [markdown]
# python only do implicit programming for same types
