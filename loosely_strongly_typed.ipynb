# %% [markdown]
# # Loosely typed vs strongly typed languages

# %% [markdown]
# - Loosely Typed ⇒ we can add string to int , int to string : 5 + “HELLO” ⇒ “5HELLO”
# - Strongly Typed ⇒ we can’t add string to int and vice versa

# %% [markdown]
# Python is strongly typed language
