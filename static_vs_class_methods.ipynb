# %%
a=257
b=257

a is b
# Out:
# False

# %% [markdown]
# ## Class Method vs static method:
#
# - class method: accepts a class paramter and can modify the class ythings (class not object)
# - static method: cant modify anything in class
