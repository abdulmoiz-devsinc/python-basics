# %% [markdown]
# | Outer | Can store lists? | Can store sets? | Can store dicts? | Can store tuples? |
# | --- | --- | --- | --- | --- |
# | list | ✅ | ✅ | ✅ | ✅ |
# | set | ❌ | ❌ | ❌ | ✅ |
# | tuple | ✅ | ✅ | ✅ | ✅ |
# | dict value | ✅ | ✅ | ✅ | ✅ |
# | dict key | ❌ | ❌ | ❌ | ✅ |
# | frozenset | ❌ | ❌ | ❌ | ✅ |
