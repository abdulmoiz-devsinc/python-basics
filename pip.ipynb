# %% [markdown]
# # PIP - Python Installer Package
# Python’s default package manager
#
# A command-line tool
#
# Responsible for downloading, installing, upgrading, and removing packages

# %% [markdown]
# Your command → pip → PyPI (or other source) → download → install → site-packages

# %% [markdown]
# pip install package (if we do in virtual env then it also install globally)
# python -m pip install package (it will only install in the virtual env)
